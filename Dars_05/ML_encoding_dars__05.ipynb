# %% [markdown]
# # Encoding

# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/sunnatabdurayimov/Downloads/Machine_Learning/encoding.csv')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Year                       1000 non-null   int64
#  1   Quarter                    1000 non-null   str
#  2   Product Model              995 non-null    str
#  3   5G Capability              975 non-null    str
#  4   Units Sold                 1000 non-null   int64
#  5   Revenue ($)                1000 non-null   float64
#  6   Market Share (%)           999 non-null    float64
#  7   Regional 5G Coverage (%)   1000 non-null   float64
#  8   5G Subscribers (millions)  1000 non-null   float64
#  9   Avg 5G Speed (Mbps)        1000 non-null   float64
#  10  Preference for 5G (%)      1000 non-null   float64
#  11  Region                     996 non-null    str
#  12  Color                      3 non-null      str
# dtypes: float64(6), int64(2), str(5)
# ...

# %%
df.head()
# Out:
#    Year Quarter  Product Model 5G Capability  Units Sold   Revenue ($)  \
# 0  2019      Q1     Galaxy S10            No       26396  4.212951e+06
# 1  2019      Q1  Galaxy Note10            No       25671  7.240266e+06
# 2  2019      Q1     Galaxy S20            No       16573  2.560833e+07
# 3  2019      Q1  Galaxy Note20            No        7177  2.198442e+07
# 4  2019      Q1     Galaxy S21            No       45633  1.634244e+07
#
#    Market Share (%)  Regional 5G Coverage (%)  5G Subscribers (millions)  \
# 0              1.04                     57.36                      39.55
# 1              2.82                     85.80                      42.58
# 2             -0.03                     47.02                       3.78
# 3              0.84                     25.70                      23.41
# 4              2.36                     89.13                      44.43
#
#    Avg 5G Speed (Mbps)  Preference for 5G (%)                Region
# ...

# %%
df.isnull().sum()
# Out:
# Year                           0
# Quarter                        0
# Product Model                  5
# 5G Capability                 25
# Units Sold                     0
# Revenue ($)                    0
# Market Share (%)               1
# Regional 5G Coverage (%)       0
# 5G Subscribers (millions)      0
# Avg 5G Speed (Mbps)            0
# Preference for 5G (%)          0
# Region                         4
# Color                        997
# dtype: int64

# %% [markdown]
# #drop

# %%
#df.drop('Color',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Year                       1000 non-null   int64
#  1   Quarter                    1000 non-null   str
#  2   Product Model              995 non-null    str
#  3   5G Capability              975 non-null    str
#  4   Units Sold                 1000 non-null   int64
#  5   Revenue ($)                1000 non-null   float64
#  6   Market Share (%)           999 non-null    float64
#  7   Regional 5G Coverage (%)   1000 non-null   float64
#  8   5G Subscribers (millions)  1000 non-null   float64
#  9   Avg 5G Speed (Mbps)        1000 non-null   float64
#  10  Preference for 5G (%)      1000 non-null   float64
#  11  Region                     996 non-null    str
#  12  Color                      3 non-null      str
# dtypes: float64(6), int64(2), str(5)
# ...

# %%
#df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Year                       3 non-null      int64
#  1   Quarter                    3 non-null      str
#  2   Product Model              3 non-null      str
#  3   5G Capability              3 non-null      str
#  4   Units Sold                 3 non-null      int64
#  5   Revenue ($)                3 non-null      float64
#  6   Market Share (%)           3 non-null      float64
#  7   Regional 5G Coverage (%)   3 non-null      float64
#  8   5G Subscribers (millions)  3 non-null      float64
#  9   Avg 5G Speed (Mbps)        3 non-null      float64
#  10  Preference for 5G (%)      3 non-null      float64
#  11  Region                     3 non-null      str
#  12  Color                      3 non-null      str
# dtypes: float64(6), int64(2), str(5)
# ...

# %%
df.isnull().sum()
# Out:
# Year                           0
# Quarter                        0
# Product Model                  5
# 5G Capability                 25
# Units Sold                     0
# Revenue ($)                    0
# Market Share (%)               1
# Regional 5G Coverage (%)       0
# 5G Subscribers (millions)      0
# Avg 5G Speed (Mbps)            0
# Preference for 5G (%)          0
# Region                         4
# Color                        997
# dtype: int64

# %%
df.fillna({'Region':df['Region'].mode()[0]},inplace=True)
# Out:
#      Year Quarter  Product Model 5G Capability  Units Sold   Revenue ($)  \
# 0    2019      Q1     Galaxy S10            No       26396  4.212951e+06
# 1    2019      Q1  Galaxy Note10            No       25671  7.240266e+06
# 2    2019      Q1     Galaxy S20            No       16573  2.560833e+07
# 3    2019      Q1  Galaxy Note20            No        7177  2.198442e+07
# 4    2019      Q1     Galaxy S21            No       45633  1.634244e+07
# ..    ...     ...            ...           ...         ...           ...
# 995  2023      Q4  Galaxy S22 5G           Yes       36216  2.995937e+07
# 996  2022      Q2     Galaxy S21            No       33806  2.369938e+07
# 997  2022      Q1     Galaxy S10            No       23678  2.330203e+07
# 998  2023      Q4  Galaxy Note10            No       35697  1.946256e+07
# 999  2020      Q4  Galaxy Note20            No        7473  1.962177e+07
#
#      Market Share (%)  Regional 5G Coverage (%)  5G Subscribers (millions)  \
# ...

# %%
df.fillna({'Market Share (%)':df['Market Share (%)'].mean()},inplace=True)
# Out:
#      Year Quarter  Product Model 5G Capability  Units Sold   Revenue ($)  \
# 0    2019      Q1     Galaxy S10            No       26396  4.212951e+06
# 1    2019      Q1  Galaxy Note10            No       25671  7.240266e+06
# 2    2019      Q1     Galaxy S20            No       16573  2.560833e+07
# 3    2019      Q1  Galaxy Note20            No        7177  2.198442e+07
# 4    2019      Q1     Galaxy S21            No       45633  1.634244e+07
# ..    ...     ...            ...           ...         ...           ...
# 995  2023      Q4  Galaxy S22 5G           Yes       36216  2.995937e+07
# 996  2022      Q2     Galaxy S21            No       33806  2.369938e+07
# 997  2022      Q1     Galaxy S10            No       23678  2.330203e+07
# 998  2023      Q4  Galaxy Note10            No       35697  1.946256e+07
# 999  2020      Q4  Galaxy Note20            No        7473  1.962177e+07
#
#      Market Share (%)  Regional 5G Coverage (%)  5G Subscribers (millions)  \
# ...

# %%
df.fillna({'5G Capability':'No'},inplace=True)
# Out:
#      Year Quarter  Product Model 5G Capability  Units Sold   Revenue ($)  \
# 0    2019      Q1     Galaxy S10            No       26396  4.212951e+06
# 1    2019      Q1  Galaxy Note10            No       25671  7.240266e+06
# 2    2019      Q1     Galaxy S20            No       16573  2.560833e+07
# 3    2019      Q1  Galaxy Note20            No        7177  2.198442e+07
# 4    2019      Q1     Galaxy S21            No       45633  1.634244e+07
# ..    ...     ...            ...           ...         ...           ...
# 995  2023      Q4  Galaxy S22 5G           Yes       36216  2.995937e+07
# 996  2022      Q2     Galaxy S21            No       33806  2.369938e+07
# 997  2022      Q1     Galaxy S10            No       23678  2.330203e+07
# 998  2023      Q4  Galaxy Note10            No       35697  1.946256e+07
# 999  2020      Q4  Galaxy Note20            No        7473  1.962177e+07
#
#      Market Share (%)  Regional 5G Coverage (%)  5G Subscribers (millions)  \
# ...

# %%
df.isnull().sum()
# Out:
# Year                           0
# Quarter                        0
# Product Model                  5
# 5G Capability                  0
# Units Sold                     0
# Revenue ($)                    0
# Market Share (%)               0
# Regional 5G Coverage (%)       0
# 5G Subscribers (millions)      0
# Avg 5G Speed (Mbps)            0
# Preference for 5G (%)          0
# Region                         0
# Color                        997
# dtype: int64

# %%
df.fillna({'Product Model':df['Product Model'].mode()[0]},inplace=True)
# Out:
#      Year Quarter  Product Model 5G Capability  Units Sold   Revenue ($)  \
# 0    2019      Q1     Galaxy S10            No       26396  4.212951e+06
# 1    2019      Q1  Galaxy Note10            No       25671  7.240266e+06
# 2    2019      Q1     Galaxy S20            No       16573  2.560833e+07
# 3    2019      Q1  Galaxy Note20            No        7177  2.198442e+07
# 4    2019      Q1     Galaxy S21            No       45633  1.634244e+07
# ..    ...     ...            ...           ...         ...           ...
# 995  2023      Q4  Galaxy S22 5G           Yes       36216  2.995937e+07
# 996  2022      Q2     Galaxy S21            No       33806  2.369938e+07
# 997  2022      Q1     Galaxy S10            No       23678  2.330203e+07
# 998  2023      Q4  Galaxy Note10            No       35697  1.946256e+07
# 999  2020      Q4  Galaxy Note20            No        7473  1.962177e+07
#
#      Market Share (%)  Regional 5G Coverage (%)  5G Subscribers (millions)  \
# ...

# %%
df.isnull().sum()
# Out:
# Year                           0
# Quarter                        0
# Product Model                  0
# 5G Capability                  0
# Units Sold                     0
# Revenue ($)                    0
# Market Share (%)               0
# Regional 5G Coverage (%)       0
# 5G Subscribers (millions)      0
# Avg 5G Speed (Mbps)            0
# Preference for 5G (%)          0
# Region                         0
# Color                        997
# dtype: int64

# %%
df.fillna({'Color':df['Color'].mode()[0]},inplace=True)
# Out:
#      Year Quarter  Product Model 5G Capability  Units Sold   Revenue ($)  \
# 0    2019      Q1     Galaxy S10            No       26396  4.212951e+06
# 1    2019      Q1  Galaxy Note10            No       25671  7.240266e+06
# 2    2019      Q1     Galaxy S20            No       16573  2.560833e+07
# 3    2019      Q1  Galaxy Note20            No        7177  2.198442e+07
# 4    2019      Q1     Galaxy S21            No       45633  1.634244e+07
# ..    ...     ...            ...           ...         ...           ...
# 995  2023      Q4  Galaxy S22 5G           Yes       36216  2.995937e+07
# 996  2022      Q2     Galaxy S21            No       33806  2.369938e+07
# 997  2022      Q1     Galaxy S10            No       23678  2.330203e+07
# 998  2023      Q4  Galaxy Note10            No       35697  1.946256e+07
# 999  2020      Q4  Galaxy Note20            No        7473  1.962177e+07
#
#      Market Share (%)  Regional 5G Coverage (%)  5G Subscribers (millions)  \
# ...

# %%
df.nunique()
# Out:
# Year                           6
# Quarter                        4
# Product Model                 15
# 5G Capability                  2
# Units Sold                   354
# Revenue ($)                  360
# Market Share (%)             275
# Regional 5G Coverage (%)     344
# 5G Subscribers (millions)    350
# Avg 5G Speed (Mbps)          358
# Preference for 5G (%)        347
# Region                         5
# Color                          3
# dtype: int64

# %% [markdown]
# # One-Hot

# %%
dummies=pd.get_dummies(df['Color'],prefix='ustun',dtype=int)

# %%
dummies
# Out:
#      ustun_Blue  ustun_Green  ustun_Red
# 0             0            0          1
# 1             0            1          0
# 2             1            0          0
# 3             1            0          0
# 4             1            0          0
# ..          ...          ...        ...
# 995           1            0          0
# 996           1            0          0
# 997           1            0          0
# 998           1            0          0
# 999           1            0          0
#
# [1000 rows x 3 columns]

# %%
df=pd.concat([df.drop(columns=['Color']),dummies],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Year                       1000 non-null   int64
#  1   Quarter                    1000 non-null   str
#  2   Product Model              1000 non-null   str
#  3   5G Capability              1000 non-null   str
#  4   Units Sold                 1000 non-null   int64
#  5   Revenue ($)                1000 non-null   float64
#  6   Market Share (%)           1000 non-null   float64
#  7   Regional 5G Coverage (%)   1000 non-null   float64
#  8   5G Subscribers (millions)  1000 non-null   float64
#  9   Avg 5G Speed (Mbps)        1000 non-null   float64
#  10  Preference for 5G (%)      1000 non-null   float64
#  11  Region                     1000 non-null   str
#  12  ustun_Blue                 1000 non-null   int64
# ...

# %%
df.head()
# Out:
#    Year Quarter  Product Model 5G Capability  Units Sold   Revenue ($)  \
# 0  2019      Q1     Galaxy S10            No       26396  4.212951e+06
# 1  2019      Q1  Galaxy Note10            No       25671  7.240266e+06
# 2  2019      Q1     Galaxy S20            No       16573  2.560833e+07
# 3  2019      Q1  Galaxy Note20            No        7177  2.198442e+07
# 4  2019      Q1     Galaxy S21            No       45633  1.634244e+07
#
#    Market Share (%)  Regional 5G Coverage (%)  5G Subscribers (millions)  \
# 0              1.04                     57.36                      39.55
# 1              2.82                     85.80                      42.58
# 2             -0.03                     47.02                       3.78
# 3              0.84                     25.70                      23.41
# 4              2.36                     89.13                      44.43
#
#    Avg 5G Speed (Mbps)  Preference for 5G (%)                Region  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()

# %%
encoder
# Out:
# LabelEncoder()

# %%
df['Region']=encoder.fit_transform(df['Region'])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Year                       1000 non-null   int64
#  1   Quarter                    1000 non-null   str
#  2   Product Model              1000 non-null   str
#  3   5G Capability              1000 non-null   str
#  4   Units Sold                 1000 non-null   int64
#  5   Revenue ($)                1000 non-null   float64
#  6   Market Share (%)           1000 non-null   float64
#  7   Regional 5G Coverage (%)   1000 non-null   float64
#  8   5G Subscribers (millions)  1000 non-null   float64
#  9   Avg 5G Speed (Mbps)        1000 non-null   float64
#  10  Preference for 5G (%)      1000 non-null   float64
#  11  Region                     1000 non-null   int64
#  12  ustun_Blue                 1000 non-null   int64
# ...

# %%
df['Quarter']=encoder.fit_transform(df['Quarter'])

# %%
df['5G Capability']=encoder.fit_transform(df['5G Capability'])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Year                       1000 non-null   int64
#  1   Quarter                    1000 non-null   int64
#  2   Product Model              1000 non-null   str
#  3   5G Capability              1000 non-null   int64
#  4   Units Sold                 1000 non-null   int64
#  5   Revenue ($)                1000 non-null   float64
#  6   Market Share (%)           1000 non-null   float64
#  7   Regional 5G Coverage (%)   1000 non-null   float64
#  8   5G Subscribers (millions)  1000 non-null   float64
#  9   Avg 5G Speed (Mbps)        1000 non-null   float64
#  10  Preference for 5G (%)      1000 non-null   float64
#  11  Region                     1000 non-null   int64
#  12  ustun_Blue                 1000 non-null   int64
# ...

# %%
df.head()
# Out:
#    Year  Quarter  Product Model  5G Capability  Units Sold   Revenue ($)  \
# 0  2019        0     Galaxy S10              0       26396  4.212951e+06
# 1  2019        0  Galaxy Note10              0       25671  7.240266e+06
# 2  2019        0     Galaxy S20              0       16573  2.560833e+07
# 3  2019        0  Galaxy Note20              0        7177  2.198442e+07
# 4  2019        0     Galaxy S21              0       45633  1.634244e+07
#
#    Market Share (%)  Regional 5G Coverage (%)  5G Subscribers (millions)  \
# 0              1.04                     57.36                      39.55
# 1              2.82                     85.80                      42.58
# 2             -0.03                     47.02                       3.78
# 3              0.84                     25.70                      23.41
# 4              2.36                     89.13                      44.43
#
#    Avg 5G Speed (Mbps)  Preference for 5G (%)  Region  ustun_Blue  \
# ...
