# %% [markdown]
# # Model review

# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/sunnatabdurayimov/Downloads/islamic_Pilgrimage.csv')

# %% [markdown]
# # Data bilan tanishuv

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4455 entries, 0 to 4454
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     4455 non-null   int64
#  1   Country                  4455 non-null   str
#  2   Pilgrimage_Type          4455 non-null   str
#  3   Total_Pilgrims           4455 non-null   int64
#  4   Male_Percentage          4455 non-null   float64
#  5   Female_Percentage        4455 non-null   float64
#  6   Average_Age              4453 non-null   float64
#  7   Average_Travel_Cost_USD  4455 non-null   float64
#  8   Visa_Approval_Rate       4453 non-null   float64
#  9   Flights_Arranged         4452 non-null   float64
#  10  Hotels_Booked            4453 non-null   float64
#  11  Satisfaction_Rating      4455 non-null   float64
#  12  Economic_Impact_USD      4455 non-null   float64
# dtypes: float64(9), int64(2), str(2)
# memory usage: 452.6 KB

# %%
df.head()
# Out:
#    Year       Country Pilgrimage_Type  Total_Pilgrims  Male_Percentage  \
# 0  2000      Pakistan            Hajj          126958            60.93
# 1  2000      Pakistan           Umrah          180203            47.86
# 2  2000      Pakistan         Ziyarat          352449            55.50
# 3  2000  Saudi Arabia            Hajj           89654            57.37
# 4  2000  Saudi Arabia           Umrah          146699            63.84
#
#    Female_Percentage  Average_Age  Average_Travel_Cost_USD  \
# 0              39.07         33.5                  9686.76
# 1              52.14         47.5                  2092.32
# 2              44.50         41.0                  4557.91
# 3              42.63         39.5                 11823.92
# 4              36.16         44.9                  5546.87
#
#    Visa_Approval_Rate  Flights_Arranged  Hotels_Booked  Satisfaction_Rating  \
# 0               87.31             141.0          224.0                 3.12
# ...

# %%
df.isnull().sum()
# Out:
# Year                       0
# Country                    0
# Pilgrimage_Type            0
# Total_Pilgrims             0
# Male_Percentage            0
# Female_Percentage          0
# Average_Age                2
# Average_Travel_Cost_USD    0
# Visa_Approval_Rate         2
# Flights_Arranged           3
# Hotels_Booked              2
# Satisfaction_Rating        0
# Economic_Impact_USD        0
# dtype: int64

# %% [markdown]
# # Data preprocessing

# %%
df.columns
# Out:
# Index(['Year', 'Country', 'Pilgrimage_Type', 'Total_Pilgrims',
#        'Male_Percentage', 'Female_Percentage', 'Average_Age',
#        'Average_Travel_Cost_USD', 'Visa_Approval_Rate', 'Flights_Arranged',
#        'Hotels_Booked', 'Satisfaction_Rating', 'Economic_Impact_USD'],
#       dtype='str')

# %%
for col in df.columns:
    if df[col].isnull().any():
        if df[col].dtype=='float64':
            df.fillna({col:df[col].mean()},inplace=True)

# %%
df.isnull().sum()
# Out:
# Year                       0
# Country                    0
# Pilgrimage_Type            0
# Total_Pilgrims             0
# Male_Percentage            0
# Female_Percentage          0
# Average_Age                0
# Average_Travel_Cost_USD    0
# Visa_Approval_Rate         0
# Flights_Arranged           0
# Hotels_Booked              0
# Satisfaction_Rating        0
# Economic_Impact_USD        0
# dtype: int64

# %%
df.head()
# Out:
#    Year       Country Pilgrimage_Type  Total_Pilgrims  Male_Percentage  \
# 0  2000      Pakistan            Hajj          126958            60.93
# 1  2000      Pakistan           Umrah          180203            47.86
# 2  2000      Pakistan         Ziyarat          352449            55.50
# 3  2000  Saudi Arabia            Hajj           89654            57.37
# 4  2000  Saudi Arabia           Umrah          146699            63.84
#
#    Female_Percentage  Average_Age  Average_Travel_Cost_USD  \
# 0              39.07         33.5                  9686.76
# 1              52.14         47.5                  2092.32
# 2              44.50         41.0                  4557.91
# 3              42.63         39.5                 11823.92
# 4              36.16         44.9                  5546.87
#
#    Visa_Approval_Rate  Flights_Arranged  Hotels_Booked  Satisfaction_Rating  \
# 0               87.31             141.0          224.0                 3.12
# ...

# %% [markdown]
# # Encoding

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# %%
encoder=LabelEncoder()

# %%
encoder
# Out:
# LabelEncoder()

# %%
df.nunique()
# Out:
# Year                         27
# Country                      55
# Pilgrimage_Type               3
# Total_Pilgrims             4436
# Male_Percentage            1767
# Female_Percentage          1767
# Average_Age                 302
# Average_Travel_Cost_USD    4446
# Visa_Approval_Rate         2290
# Flights_Arranged            481
# Hotels_Booked               291
# Satisfaction_Rating         201
# Economic_Impact_USD        4455
# dtype: int64

# %%
for col in df.columns:
    if df[col].dtype=='str':
        df[col]=encoder.fit_transform(df[col])

# %%
df.head()
# Out:
#    Year  Country  Pilgrimage_Type  Total_Pilgrims  Male_Percentage  \
# 0  2000       33                0          126958            60.93
# 1  2000       33                1          180203            47.86
# 2  2000       33                2          352449            55.50
# 3  2000       37                0           89654            57.37
# 4  2000       37                1          146699            63.84
#
#    Female_Percentage  Average_Age  Average_Travel_Cost_USD  \
# 0              39.07         33.5                  9686.76
# 1              52.14         47.5                  2092.32
# 2              44.50         41.0                  4557.91
# 3              42.63         39.5                 11823.92
# 4              36.16         44.9                  5546.87
#
#    Visa_Approval_Rate  Flights_Arranged  Hotels_Booked  Satisfaction_Rating  \
# 0               87.31             141.0          224.0                 3.12
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4455 entries, 0 to 4454
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     4455 non-null   int64
#  1   Country                  4455 non-null   int64
#  2   Pilgrimage_Type          4455 non-null   int64
#  3   Total_Pilgrims           4455 non-null   int64
#  4   Male_Percentage          4455 non-null   float64
#  5   Female_Percentage        4455 non-null   float64
#  6   Average_Age              4455 non-null   float64
#  7   Average_Travel_Cost_USD  4455 non-null   float64
#  8   Visa_Approval_Rate       4455 non-null   float64
#  9   Flights_Arranged         4455 non-null   float64
#  10  Hotels_Booked            4455 non-null   float64
#  11  Satisfaction_Rating      4455 non-null   float64
#  12  Economic_Impact_USD      4455 non-null   float64
# dtypes: float64(9), int64(4)
# memory usage: 452.6 KB

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaler
# Out:
# MinMaxScaler()

# %%
num_col=df.select_dtypes(include=['int64','float64']).columns.drop('Average_Travel_Cost_USD')

# %%
num_col
# Out:
# Index(['Year', 'Country', 'Pilgrimage_Type', 'Total_Pilgrims',
#        'Male_Percentage', 'Female_Percentage', 'Average_Age',
#        'Visa_Approval_Rate', 'Flights_Arranged', 'Hotels_Booked',
#        'Satisfaction_Rating', 'Economic_Impact_USD'],
#       dtype='str')

# %%
df[num_col]=scaler.fit_transform(df[num_col])

# %%
df.head()
# Out:
#    Year   Country  Pilgrimage_Type  Total_Pilgrims  Male_Percentage  \
# 0   0.0  0.611111              0.0        0.246410           0.7965
# 1   0.0  0.611111              0.5        0.353993           0.1430
# 2   0.0  0.611111              1.0        0.702021           0.5250
# 3   0.0  0.685185              0.0        0.171036           0.6185
# 4   0.0  0.685185              0.5        0.286297           0.9420
#
#    Female_Percentage  Average_Age  Average_Travel_Cost_USD  \
# 0             0.2035     0.183333                  9686.76
# 1             0.8570     0.650000                  2092.32
# 2             0.4750     0.433333                  4557.91
# 3             0.3815     0.383333                 11823.92
# 4             0.0580     0.563333                  5546.87
#
#    Visa_Approval_Rate  Flights_Arranged  Hotels_Booked  Satisfaction_Rating  \
# 0            0.596897          0.252610       0.740484                0.060
# ...

# %% [markdown]
# # Algorithm selection

# %%
from sklearn.linear_model import LinearRegression
lir=LinearRegression()
lir
# Out:
# LinearRegression()

# %%
#x--inputs
x=df.drop('Average_Travel_Cost_USD',axis=1)

# %%
x
# Out:
#       Year   Country  Pilgrimage_Type  Total_Pilgrims  Male_Percentage  \
# 0      0.0  0.611111              0.0        0.246410           0.7965
# 1      0.0  0.611111              0.5        0.353993           0.1430
# 2      0.0  0.611111              1.0        0.702021           0.5250
# 3      0.0  0.685185              0.0        0.171036           0.6185
# 4      0.0  0.685185              0.5        0.286297           0.9420
# ...    ...       ...              ...             ...              ...
# 4450   1.0  0.851852              0.5        0.044320           0.8505
# 4451   1.0  0.851852              1.0        0.150162           0.0455
# 4452   1.0  0.055556              0.0        0.938774           0.8935
# 4453   1.0  0.055556              0.5        0.447919           0.4810
# 4454   1.0  0.055556              1.0        0.804554           0.4260
#
#       Female_Percentage  Average_Age  Visa_Approval_Rate  Flights_Arranged  \
# ...

# %%
# y---output
y=df['Average_Travel_Cost_USD']

# %%
y
# Out:
# 0        9686.76
# 1        2092.32
# 2        4557.91
# 3       11823.92
# 4        5546.87
#           ...
# 4450     6282.84
# 4451    10381.19
# 4452     9258.00
# 4453     5531.26
# 4454     6739.69
# Name: Average_Travel_Cost_USD, Length: 4455, dtype: float64

# %% [markdown]
# # train

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (3564, 12)

# %%
x_test.shape
# Out:
# (891, 12)

# %%
y_train.shape
# Out:
# (3564,)

# %%
y_test.shape
# Out:
# (891,)

# %%
lir.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Prediction

# %%
y_pred=lir.predict(x_test)

# %%
y_pred[0]
# Out:
# np.float64(8958.020434959833)

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
mae=mean_absolute_error(y_test,y_pred)
mse= mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)

# %%
print('mae=',mae)
print('mse=',mse)
print('r2=',r2)
# Out:
# mae= 1801.5269798523611
# mse= 4843864.168185441
# r2= 0.4932647036716652
