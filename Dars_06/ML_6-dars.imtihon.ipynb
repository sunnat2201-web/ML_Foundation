# %%
# 2ga bo'linish
a=3683530
if a%2==0:
    print("Yaxshi")


else:
    print("Yomon")
# Out:
# Yaxshi

# %%
#musbat or manfiy
a=-554
if  a>0:
    print('Yaxshi')
elif a==0:
    print('Nol')
else:
    print('Yomon')
# Out:
# Yomon

# %%
# 5ga va 3ga bo'linish
a=225
if   a % 5 == 0 and a % 3 ==0:
    print('Good')

else:
    print('Bad')
# Out:
# Good

# %%
#bosh harf
matn='askar'
if matn[0].upper()=="A":
    print('Yaxshi')
else:
    print('Yomon')
# Out:
# Yaxshi

# %%
#oxirgi harf
a="matn"
if a[-1].upper()=='A':
    print('yaxshi')

else:
    print('yomon')
# Out:
# yomon

# %%
# bosh va oxirgi harf
a='baqa'
if  a[0].upper()=='B' and a[-1].upper()=='A':
    print('YAXSHI')
else:
    print('YOMON')
# Out:
# YAXSHI

# %%
#musbat manfiy
c=0
if c>0:
    print('Musbat son')

elif c==0:
    print('Nol')   

else:
    print('Manfiy son')
# Out:
# Nol
